# %% [markdown]
# # Дана функция f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

# %% [markdown]
# ## 1. Определить корни:
# Судя по графику (пункт №4) видно, что функция является синусоидной и имеет бесконечное количество корней.

# %% [markdown]
# ## 2. Найти интервалы, на которых функция возрастает:
# Исходя из того что функция немонотонная, возрастающих интервалов имеется бесконечное множество.

# %% [markdown]
# ## 3. Найти интервалы, на которых функция убывает
# Исходя из того что функция немонотонная, убывающих интервалов имеется бесконечное множество.

# %% [markdown]
# ## 4. Построить график:

# %%
from sympy import *

x = Symbol('x')
func=-12*sin(cos(x))*x**4 - 18*x**3+5*x**2 + 10*x - 30
plot(func,(x,-200,200))
print(func)
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %% [markdown]
# ## 5. Вычислить вершину:
# Количество вершин в данной функции так же бесконечное множество

# %% [markdown]
# ## 6. Определить промежутки, на котором f > 0:
# Количество промужетков на котором f > 0, бесконечное множество.

# %% [markdown]
# ## 7. Определить промежутки, на котором f < 0:
# Количество промужетков на котором f < 0, бесконечное множество.
